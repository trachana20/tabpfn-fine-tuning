# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, LeakyReLU, BatchNormalization
from tensorflow.keras.models import Sequential

# %%
# !pwd
# Out:
# /Users/rachana/tanpfn

# %%
import os

# Change directory to the location where gan_module.py is located
os.chdir('/Users/rachana/tanpfn/data')

# %%
# !pwd
# Out:
# /Users/rachana/tanpfn/data

# %%
# Import custom module
import gan_module_dress_sales

# %%
# Define the path to the CSV file
file_path = '/Users/rachana/tanpfn/data/dataset/dress_sales_openML.csv'

# Load and preprocess the data
data, scaler, encoder, continuous_features, categorical_features, encoded_cat_columns  = gan_module_dress_sales.load_and_preprocess_data(file_path)

# Display the preprocessed data
# data.head()
# Out:
# /Users/rachana/tanpfn/data/gan_module_dress_sales.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[encoded_cat_columns] = encoded_cats
# /Users/rachana/tanpfn/data/gan_module_dress_sales.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[encoded_cat_columns] = encoded_cats
# ...

# %%
gan_module_dress_sales.main(file_path, input_dim=100, epochs=1000, batch_size=128, num_samples=500)
# Out:
# /Users/rachana/tanpfn/data/gan_module_dress_sales.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[encoded_cat_columns] = encoded_cats
# /Users/rachana/tanpfn/data/gan_module_dress_sales.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[encoded_cat_columns] = encoded_cats
# ...
