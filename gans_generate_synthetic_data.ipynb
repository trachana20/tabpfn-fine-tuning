# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, LeakyReLU, BatchNormalization
from tensorflow.keras.models import Sequential

# %%
# !pwd
# Out:
# /Users/rachana/tanpfn

# %%
import os

# Change directory to the location where gan_module.py is located
os.chdir('/Users/rachana/tanpfn/data')

# %%
# !pwd
# Out:
# /Users/rachana/tanpfn/data

# %%
# Import custom module
import gan_module

# %%
# Define the path to the CSV file
file_path = '/Users/rachana/tanpfn/data/dataset/titanic_from_openML.csv'

# Load and preprocess the data
data, scaler, encoder, continuous_features, categorical_features, encoded_cat_columns, original_df, original_cat_features = gan_module.load_and_preprocess_data(file_path)

# Display the preprocessed data
# data.head()
# Out:
# /Users/rachana/tanpfn/data/gan_module.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[encoded_cat_columns] = encoded_cats
# /Users/rachana/tanpfn/data/gan_module.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[encoded_cat_columns] = encoded_cats
# ...

# %%
gan_module.main(file_path, input_dim=100, epochs=10000, batch_size=128, num_samples=1000)
# Out:
# /Users/rachana/tanpfn/data/gan_module.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[encoded_cat_columns] = encoded_cats
# /Users/rachana/tanpfn/data/gan_module.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[encoded_cat_columns] = encoded_cats
# ...
